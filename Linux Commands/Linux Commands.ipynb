# %%
# %%bash
#
# pwd
# Out:
# /home/millan/Documents/Linux Commands

# %%
pwd
# Out:
# '/home/millan/Documents/Linux Commands'

# %%
ls
# Out:
# 'Linux Commands(Grok)'
# 'Linux Commands.ipynb'
# 'Screenshot From 2026-02-02 17-54-40.png'
# 'Screenshot From 2026-02-02 17-54-52.png'
# 'Screenshot From 2026-02-11 07-33-59.png'
# 'Screenshot From 2026-02-11 07-34-06.png'
# 'Screenshot From 2026-02-12 18-59-01.png'
# 'Screenshot From 2026-02-12 18-59-12.png'
# 'Screenshot From 2026-02-12 18-59-23.png'
# 'Screenshot From 2026-02-12 18-59-28.png'
# 'Screenshot From 2026-02-12 19-00-07.png'
# 'Screenshot From 2026-02-12 19-00-13.png'
# 'Screenshot From 2026-02-12 19-00-24.png'
# 'Screenshot From 2026-02-12 19-00-31.png'
# 'Screenshot From 2026-02-12 19-00-39.png'
# 'Screenshot From 2026-02-12 19-01-03.png'
# 'Screenshot From 2026-02-12 19-01-08.png'
# 'Screenshot From 2026-02-12 19-01-19.png'
# 'Screenshot From 2026-02-12 19-01-22.png'
# 'Screenshot From 2026-02-12 19-01-27.png'
# 'Screenshot From 2026-02-12 19-01-31.png'
# 'Screenshot From 2026-02-12 19-01-35.png'
# 'Screenshot From 2026-02-12 19-01-39.png'
# 'Screenshot From 2026-02-12 19-01-44.png'
# 'Screenshot From 2026-02-12 19-01-49.png'
# 'Screenshot From 2026-02-12 19-01-53.png'
# 'Screenshot From 2026-02-12 19-01-56.png'
# 'Screenshot From 2026-02-12 19-02-00.png'
# 'Screenshot From 2026-02-12 19-02-04.png'
# 'Screenshot From 2026-02-12 19-02-06.png'
# 'Screenshot From 2026-02-12 19-02-13.png'
# 'Screenshot From 2026-02-12 19-02-19.png'

# %%
pwd
# Out:
# '/home/millan/Documents/Linux Commands'

# %%
cd
# Out:
# /home/millan

# %%
cd/home
# Out:
# /home

# %%
pwd
# Out:
# '/home'

# %%
ls
# Out:
# millan/

# %%
cd millan
# Out:
# /home/millan

# %%
ls
# Out:
#  albiononline/   Linux/                     Public/          Videos/
#  Desktop/        Music/                     README.md
#  Documents/      Pictures/                  Templates/
#  Downloads/     'print("Hello World").py'   Untitled.ipynb

# %%
cd Linux
# Out:
# /home/millan/Linux

# %%
ls
# Out:
#  File.txt   geminiCLI/  'print("Hello World").py'

# %%
cd
# Out:
# /home/millan

# %%
ls
# Out:
#  albiononline/   Linux/                     Public/          Videos/
#  Desktop/        Music/                     README.md
#  Documents/      Pictures/                  Templates/
#  Downloads/     'print("Hello World").py'   Untitled.ipynb

# %%
cd Documents/
# Out:
# /home/millan/Documents

# %%
ls
# Out:
# 'CLOUD_ENGINEERING_AWS '/  'Cloud Engineering Road Map'/  'Linux Commands'/

# %%
cd
# Out:
# /home/millan

# %%
ls
# Out:
#  albiononline/   Linux/                     Public/          Videos/
#  Desktop/        Music/                     README.md
#  Documents/      Pictures/                  Templates/
#  Downloads/     'print("Hello World").py'   Untitled.ipynb

# %%
cd Documents
# Out:
# /home/millan/Documents

# %%
pwd
# Out:
# '/home/millan/Documents'

# %% [markdown]
# ### 1. File and Directory Management

# %%
ls   # List directory contents
# Out:
# 'CLOUD_ENGINEERING_AWS '/  'Cloud Engineering Road Map'/  'Linux Commands'/

# %%
ls -l # Lists files with detailed information like permissions and size.
# Out:
# total 0
# drwxr-xr-x. 1 millan millan  138 Oct 28 18:04 'CLOUD_ENGINEERING_AWS '/
# drwxr-xr-x. 1 millan millan 3900 Feb  3 16:52 'Cloud Engineering Road Map'/
# drwxr-xr-x. 1 millan millan 2420 Feb 17 20:58 'Linux Commands'/

# %%
ls -a  # Lists all files, including hidden ones.
# Out:
#  ./   'CLOUD_ENGINEERING_AWS '/       .git/
#  ../  'Cloud Engineering Road Map'/  'Linux Commands'/

# %%
ls /home # Lists contents of the /home directory.
# Out:
# millan/

# %%
ls -lh # Lists files with human-readable sizes.
# Out:
# total 16K
# drwxr-xr-x. 1 millan millan  160 Oct 12 16:34  albiononline/
# drwxr-xr-x. 1 millan millan    0 Oct 12 15:39  Desktop/
# drwxr-xr-x. 1 millan millan  132 Feb 12 18:31  Documents/
# drwxr-xr-x. 1 millan millan 2.0K Feb 18 07:20  Downloads/
# drwxr-xr-x. 1 millan millan   80 Feb 15 11:19  Linux/
# drwxr-xr-x. 1 millan millan    0 Oct 12 15:39  Music/
# drwxr-xr-x. 1 millan millan   22 Oct 21 07:46  Pictures/
# -rw-r--r--. 1 millan millan   21 Feb  3 10:16 'print("Hello World").py'
# drwxr-xr-x. 1 millan millan    0 Oct 12 15:39  Public/
# -rw-r--r--. 1 millan millan   72 Dec  7 07:39  README.md
# drwxr-xr-x. 1 millan millan    0 Oct 12 15:39  Templates/
# -rw-r--r--. 1 millan millan 2.6K Feb 13 10:07  Untitled.ipynb
# drwxr-xr-x. 1 millan millan   22 Feb 12 08:16  Videos/

# %%
cd
# Out:
# /home/millan

# %%
ls
# Out:
#  albiononline/   Linux/                     Public/          Videos/
#  Desktop/        Music/                     README.md
#  Documents/      Pictures/                  Templates/
#  Downloads/     'print("Hello World").py'   Untitled.ipynb

# %%
cd Linux/
# Out:
# /home/millan/Linux

# %%
ls
# Out:
#  File.txt   geminiCLI/  'print("Hello World").py'

# %%
cd ~
# Out:
# /home/millan

# %%
pwd
# Out:
# '/home/millan'

# %%
cd ..
# Out:
# /home

# %%
cd
# Out:
# /home/millan

# %%
cd /var/log/
# Out:
# /var/log

# %%
ls
# Out:
# anaconda/          cron-20260208    libvirt/           secure
# audit/             cron-20260215    maillog            secure-20260125
# blivet-gui/        cups/            maillog-20260125   secure-20260201
# boot.log           dnf5.log         maillog-20260201   secure-20260208
# boot.log-20260210  dnf5.log.1       maillog-20260208   secure-20260215
# boot.log-20260211  dnf5.log.2       maillog-20260215   speech-dispatcher/
# boot.log-20260212  dnf5.log.3       messages           spooler
# boot.log-20260214  dnf5.log.4       messages-20260125  spooler-20260125
# boot.log-20260215  dnf.librepo.log  messages-20260201  spooler-20260201
# boot.log-20260216  dnf.log          messages-20260208  spooler-20260208
# boot.log-20260217  dnf.rpm.log      messages-20260215  spooler-20260215
# btmp               firewalld        passim/            sssd/
# btmp-20260201      gdm/             ppp/               swtpm/
# chrony/            glusterfs/       private/           tuned/
# cron               httpd/           qemu-ga/           wtmp
# cron-20260125      journal/         README@
# cron-20260201      lastlog          samba/

# %%
cd
# Out:
# /home/millan

# %%
cd Linux
# Out:
# /home/millan/Linux

# %%
cd ..
# Out:
# /home/millan

# %%
cd ..
# Out:
# /home

# %%
cd
# Out:
# /home/millan

# %%
cd Documents
# Out:
# /home/millan/Documents

# %%
cd
# Out:
# /home/millan

# %%
pwd   #print working directory
# Out:
# '/home/millan'

# %%
mkdir newdir #make directory

# %%
mkdir -p parent/child #create nested directories

# %%
mkdir dir1 dir2 #create multiple directories
# Out:
# mkdir: cannot create directory ‘dir1’: File exists
# mkdir: cannot create directory ‘dir2’: File exists

# %%
mkdir /tmp/test #create test in /tmp

# %%
mkdir -m 755 secure # Creates directory with specific permissions

# %%
pwd
# Out:
# '/home/millan'

# %%
ls
# Out:
#  albiononline/   Downloads/   Pictures/                  Templates/
#  Desktop/        Linux/      'print("Hello World").py'   Untitled.ipynb
#  dir1/           Music/       Public/                    Videos/
#  dir2/           newdir/      README.md
#  Documents/      parent/      secure/

# %%
 cd parent/
# Out:
# /home/millan/parent

# %%
ls
# Out:
# child/

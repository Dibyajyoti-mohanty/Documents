# %%
# %%bash
#
# pwd
# Out:
# /home/millan

# %%
pwd
# Out:
# '/home/millan'

# %%
ls
# Out:
#  albiononline/   Linux/     'print("Hello World").py'   Templates/
#  Desktop/        Music/      Public/                    Untitled.ipynb
#  Documents/      newdir/     README.md                  Videos/
#  Downloads/      Pictures/   secure/

# %%
pwd
# Out:
# '/home/millan'

# %%
cd
# Out:
# /home/millan

# %%
cd/home
# Out:
# /home

# %%
pwd
# Out:
# '/home'

# %%
ls
# Out:
# millan/

# %%
cd millan
# Out:
# /home/millan

# %%
ls
# Out:
#  albiononline/   Linux/     'print("Hello World").py'   Templates/
#  Desktop/        Music/      Public/                    Untitled.ipynb
#  Documents/      newdir/     README.md                  Videos/
#  Downloads/      Pictures/   secure/

# %%
cd Linux
# Out:
# /home/millan/Linux

# %%
ls
# Out:
#  File.txt   geminiCLI/  'print("Hello World").py'

# %%
cd
# Out:
# /home/millan

# %%
ls
# Out:
#  albiononline/   Linux/     'print("Hello World").py'   Templates/
#  Desktop/        Music/      Public/                    Untitled.ipynb
#  Documents/      newdir/     README.md                  Videos/
#  Downloads/      Pictures/   secure/

# %%
cd Documents/
# Out:
# /home/millan/Documents

# %%
ls
# Out:
# 'CLOUD_ENGINEERING_AWS '/  'Cloud Engineering Road Map'/  'Linux Commands'/

# %%
cd
# Out:
# /home/millan

# %%
ls
# Out:
#  albiononline/   Linux/     'print("Hello World").py'   Templates/
#  Desktop/        Music/      Public/                    Untitled.ipynb
#  Documents/      newdir/     README.md                  Videos/
#  Downloads/      Pictures/   secure/

# %%
cd Documents
# Out:
# /home/millan/Documents

# %%
pwd
# Out:
# '/home/millan/Documents'

# %% [markdown]
# ### 1. File and Directory Management

# %%
ls   # List directory contents
# Out:
# 'CLOUD_ENGINEERING_AWS '/  'Cloud Engineering Road Map'/  'Linux Commands'/

# %%
ls -l # Lists files with detailed information like permissions and size.
# Out:
# total 0
# drwxr-xr-x. 1 millan millan  138 Oct 28 18:04 'CLOUD_ENGINEERING_AWS '/
# drwxr-xr-x. 1 millan millan 3900 Feb  3 16:52 'Cloud Engineering Road Map'/
# drwxr-xr-x. 1 millan millan 2420 Feb 17 20:58 'Linux Commands'/

# %%
ls -a  # Lists all files, including hidden ones.
# Out:
#  ./   'CLOUD_ENGINEERING_AWS '/       .git/
#  ../  'Cloud Engineering Road Map'/  'Linux Commands'/

# %%
ls /home # Lists contents of the /home directory.
# Out:
# millan/

# %%
ls -lh # Lists files with human-readable sizes.
# Out:
# total 0
# drwxr-xr-x. 1 millan millan  138 Oct 28 18:04 'CLOUD_ENGINEERING_AWS '/
# drwxr-xr-x. 1 millan millan 3.9K Feb  3 16:52 'Cloud Engineering Road Map'/
# drwxr-xr-x. 1 millan millan 2.4K Feb 17 20:58 'Linux Commands'/

# %%
cd
# Out:
# /home/millan

# %%
ls
# Out:
#  albiononline/   Linux/     'print("Hello World").py'   Templates/
#  Desktop/        Music/      Public/                    Untitled.ipynb
#  Documents/      newdir/     README.md                  Videos/
#  Downloads/      Pictures/   secure/

# %%
cd Linux/
# Out:
# /home/millan/Linux

# %%
ls
# Out:
#  File.txt   geminiCLI/  'print("Hello World").py'

# %%
cd ~
# Out:
# /home/millan

# %%
pwd
# Out:
# '/home/millan'

# %%
cd ..
# Out:
# /home

# %%
cd
# Out:
# /home/millan

# %%
cd /var/log/
# Out:
# /var/log

# %%
ls
# Out:
# anaconda/          cron-20260208    libvirt/           secure
# audit/             cron-20260215    maillog            secure-20260125
# blivet-gui/        cups/            maillog-20260125   secure-20260201
# boot.log           dnf5.log         maillog-20260201   secure-20260208
# boot.log-20260211  dnf5.log.1       maillog-20260208   secure-20260215
# boot.log-20260212  dnf5.log.2       maillog-20260215   speech-dispatcher/
# boot.log-20260214  dnf5.log.3       messages           spooler
# boot.log-20260215  dnf5.log.4       messages-20260125  spooler-20260125
# boot.log-20260216  dnf.librepo.log  messages-20260201  spooler-20260201
# boot.log-20260217  dnf.log          messages-20260208  spooler-20260208
# boot.log-20260219  dnf.rpm.log      messages-20260215  spooler-20260215
# btmp               firewalld        passim/            sssd/
# btmp-20260201      gdm/             ppp/               swtpm/
# chrony/            glusterfs/       private/           tuned/
# ...

# %%
cd
# Out:
# /home/millan

# %%
cd Linux
# Out:
# /home/millan/Linux

# %%
cd ..
# Out:
# /home/millan

# %%
cd ..
# Out:
# /home

# %%
cd
# Out:
# /home/millan

# %%
cd Documents
# Out:
# /home/millan/Documents

# %%
cd
# Out:
# /home/millan

# %%
pwd   #print working directory
# Out:
# '/home/millan'

# %%
mkdir newdir #make directory
# Out:
# mkdir: cannot create directory ‘newdir’: File exists

# %%
mkdir -p parent/child #create nested directories

# %%
mkdir dir1 dir2 #create multiple directories

# %%
mkdir /tmp/test #create test in /tmp
# Out:
# mkdir: cannot create directory ‘/tmp/test’: File exists

# %%
mkdir -m 755 secure # Creates directory with specific permissions
# Out:
# mkdir: cannot create directory ‘secure’: File exists

# %%
pwd
# Out:
# '/home/millan'

# %%
ls
# Out:
#  albiononline/   Downloads/   Pictures/                  Templates/
#  Desktop/        Linux/      'print("Hello World").py'   Untitled.ipynb
#  dir1/           Music/       Public/                    Videos/
#  dir2/           newdir/      README.md
#  Documents/      parent/      secure/

# %%
 cd parent/
# Out:
# /home/millan/parent

# %%
ls
# Out:
# child/

# %%
pwd
# Out:
# '/home/millan/parent'

# %%
mkdir empty

# %%
ls
# Out:
# child/  empty/

# %%
rmdir empty

# %%
ls
# Out:
# child/

# %%
cd
# Out:
# /home/millan

# %%
ls
# Out:
#  albiononline/   Downloads/   Pictures/                  Templates/
#  Desktop/        Linux/      'print("Hello World").py'   Untitled.ipynb
#  dir1/           Music/       Public/                    Videos/
#  dir2/           newdir/      README.md
#  Documents/      parent/      secure/

# %%
rmdir dir1 dir2

# %%
ls
# Out:
#  albiononline/   Linux/    Pictures/                  secure/
#  Desktop/        Music/   'print("Hello World").py'   Templates/
#  Documents/      newdir/   Public/                    Untitled.ipynb
#  Downloads/      parent/   README.md                  Videos/

# %%
rmdir -p parent/child

# %%
ls
# Out:
#  albiononline/   Linux/     'print("Hello World").py'   Templates/
#  Desktop/        Music/      Public/                    Untitled.ipynb
#  Documents/      newdir/     README.md                  Videos/
#  Downloads/      Pictures/   secure/

# %%
cd Templates/
# Out:
# /home/millan/Templates

# %%
ls

# %%
cd
# Out:
# /home/millan

# %%
ls
# Out:
#  albiononline/   Linux/     'print("Hello World").py'   Templates/
#  Desktop/        Music/      Public/                    Untitled.ipynb
#  Documents/      newdir/     README.md                  Videos/
#  Downloads/      Pictures/   secure/

# %%
ls -a
# Out:
#  ./              .gemini/             'print("Hello World").py'
#  ../             .git/                 Public/
#  albiononline/   .gitconfig            README.md
#  .antigravity/   .ipynb_checkpoints/   secure/
#  .bash_history   .ipython/             .steam/
#  .bash_logout    .jupyter/             .steampath@
#  .bash_profile   Linux/                .steampid@
#  .bashrc         .local/               Templates/
#  .cache/         .mozilla/             Untitled.ipynb
#  .config/        Music/                .var/
#  Desktop/        newdir/               Videos/
#  Documents/      .npm/                 .vscode/
#  .dotnet/        Pictures/
#  Downloads/      .pki/

# %%
ls
# Out:
#  albiononline/   Linux/     'print("Hello World").py'   Templates/
#  Desktop/        Music/      Public/                    Untitled.ipynb
#  Documents/      newdir/     README.md                  Videos/
#  Downloads/      Pictures/   secure/

# %%
rm file.txt
# Out:
# rm: cannot remove 'file.txt': No such file or directory

# %%
ls
# Out:
#  albiononline/   Linux/     'print("Hello World").py'   Templates/
#  Desktop/        Music/      Public/                    Untitled.ipynb
#  Documents/      newdir/     README.md                  Videos/
#  Downloads/      Pictures/   secure/

# %%
# %%bash
#
# touch file.txt

# %%
ls
# Out:
#  albiononline/   file.txt   Pictures/                  secure/
#  Desktop/        Linux/    'print("Hello World").py'   Templates/
#  Documents/      Music/     Public/                    Untitled.ipynb
#  Downloads/      newdir/    README.md                  Videos/

# %%
! touch -t 202601010000 file
